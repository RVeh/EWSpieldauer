# %% [markdown]
# # 🌐 3D-Darstellung der Erwartungswerte $\mathbb{E}(V)$ bei drei Feldern
#
# In diesem Notebook werden alle möglichen Chipverteilungen $V = (v_1, v_2, v_3)$ mit $\sum v_j = n$
# visualisiert – als 3D-Fläche über dem Punkt $(v_1, v_2)$.
#
# Jeder Punkt in der Fläche zeigt den Erwartungswert $\mathbb{E}(V)$ als Höhe.
#
# ---
#
# ## 🔍 Ziel der Darstellung
#
# - 🔢 Struktur in der Verteilung der Erwartungswerte erkennen
# - 🧭 Regionen mit besonders hohen oder niedrigen Werten entdecken
# - 🎓 Verständnis für die Rolle einzelner Chips gewinnen
#
# ---
#
# ## ⚙️ Voraussetzungen
#
# Diese Darstellung ist **nur bei $m = 3$ Feldern** möglich,
# da sonst eine 3D-Darstellung nicht sinnvoll interpretierbar wäre.
#
# Die Chipverteilungen liegen im **ganzzahligen Dreieck** $v_1 + v_2 + v_3 = n$
# und die Höhe entspricht dem zugehörigen Wert $\mathbb{E}(v_1, v_2, v_3)$.
#
# ---
#
# ## 🚀 Start
#
# In der nächsten Zelle steht das Programm zur 3D-Darstellung.
#
# > 🔄 **Bitte führen Sie alle Zellen einmal aus**, damit alle Werte korrekt angezeigt werden:
# >
# > - Menü: `Run` → `Run All Cells`
# > - oder: Klicken SIe auf das ▶️-Symbol oben, falls die nächste Zelle ausgewählt wurde.
#
# ---

# %%
# Das zugehötige Programm mit den Eingaben (veränderbar)

from chipspiel_utils import plot_EVs_3D, alle_EVs
from fractions import Fraction

# Gleichverteilung
p = [Fraction(1, 2), Fraction(1, 4), Fraction(1, 4)]  # nur m = 3 möglich
n = 6    # Anzahl an Chips

# Berechung
werte = alle_EVs(p, 3, n)

# 3D-Ausgabe
plot_EVs_3D(werte, title="3D-Darstellung der Erwartungswerte", graustufen=False)

if sum(p) != 1:
    print("⚠️  Wahrscheinlichkeiten summieren sich nicht zu 1.")
